# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID: Ritesh Kumar and 1001722622

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Create a folder and name it 'yourNetID_PA3'
#
# Step 2: Rename this submission file as 'yourNetID_PA3.ipynb' and place it inside the folder 'yourNetID_PA3'
#
# Step 3: Rename the updated dataset file 'dataset.csv' and place it inside the folder 'yourNetID_PA3'
#
# Step 4: Your submission folder should include ONLY the following files:
#     * apriory.py,
#     * yourNetID_PA3.ipynb,
#     * dataset.csv,
#     * toyDS.csv
#
# Step 5: Zip this folder and submit it on BB. Your final submission folder name should be 'yourNetID_PA3.ZIP'

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Note that this is an individual assignment.
# - Be familiar with the algorithm and with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Random Shopping cart' dataset [01],
# * and the Apriori Algorithm (apriory.py)[02]. Note that the apriory.py file is modified to run with Python 3.

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries
import dateutil

# Import your Libraries
#Array processing
import numpy as np

#Data analysis, wrangling and common exploratory operations
import pandas as pd

from subprocess import check_output
import csv
import re
from datetime import datetime

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
from IPython.display import Image
print ('ScreenShot of the data.csv')
Image("SampleScreen01.png")
# Out:
# ScreenShot of the data.csv

# %%
# # #  Solution  # # #

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
df_item = pd.read_csv('dataset_group.csv', delimiter = ',',header = None);

df_item.columns = ['Date', 'Bill', 'Item']
df_item['Date'] = df_item['Date'].apply(dateutil.parser.parse, dayfirst=True);

df_items = df_item.groupby(['Date','Bill'])['Item'].unique()
df = []
for i,j in df_items.iteritems():
    df.append(j)
        
df=pd.DataFrame(df)

df.to_csv('dataset.csv', index=False,header = 0)

print('First 7 transactions of the dataset.csv');
df.head(7)
# Out:
# First 7 transactions of the dataset.csv
#                   0             1              2           3             4   \
# 0             yogurt          pork  sandwich bags  lunch meat  all- purpose
# 1       toilet paper       shampoo      hand soap     waffles    vegetables
# 2               soda          pork           soap   ice cream  toilet paper
# 3            cereals         juice     lunch meat        soda  toilet paper
# 4    sandwich loaves         pasta      tortillas       mixes     hand soap
# 5  laundry detergent  toilet paper           eggs  vegetables        bagels
# 6   individual meals  paper towels      tortillas  vegetables          milk
#
#                              5           6                             7   \
# 0                         flour        soda                        butter
# 1                       cheeses       mixes                          milk
# 2                  dinner rolls   hand soap               spaghetti sauce
# 3                  all- purpose        None                          None
# 4                  toilet paper  vegetables                  paper towels
# 5  dishwashing liquid/detergent     cereals                  paper towels
# 6                     ice cream       juice  dishwashing liquid/detergent
#
#               8                  9   ...            16            17  \
# 0     vegetables               beef  ...     ice cream          None
# 1  sandwich bags  laundry detergent  ...          None          None
# 2           milk            ketchup  ...    lunch meat       cereals
# 3           None               None  ...          None          None
# 4          flour               pork  ...  dinner rolls  all- purpose
# 5         butter            shampoo  ...       ketchup  all- purpose
# 6           soap      sandwich bags  ...          beef          eggs
#
#                 18      19    20    21    22    23    24    25
# 0             None    None  None  None  None  None  None  None
# 1             None    None  None  None  None  None  None  None
# 2          cheeses    eggs  None  None  None  None  None  None
# 3             None    None  None  None  None  None  None  None
# 4             soda  yogurt  None  None  None  None  None  None
# 5             milk    None  None  None  None  None  None  None
# 6  spaghetti sauce  fruits  None  None  None  None  None  None
#
# [7 rows x 26 columns]

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 1 (minimum support=0.30 and minimum confidence=0.20)')
print ('Case 1 Reasoning: Items ocurring more than 20% in dataset. With more than 20% likeliness of items purchased together. \nKeeping lower values for min_support and min_confidence we can see high ocuurence of different items and more items association. ')
print ('Case 1 Output:')
# %run apriori.py -f DATASET.csv -s 0.20 -c 0.20
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
# Case 1 (minimum support=0.30 and minimum confidence=0.50)
# Case 1 Reasoning: Items ocurring more than 30% in dataset. With more than 60% likeliness of items purchased together.
# Keeping lower values for min_support and min_confidence we can see high ocuurence of different items and more items association.
# Case 1 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables', 'pork') , 0.270
# item: ('vegetables', 'hand soap') , 0.270
# item: ('vegetables', 'flour') , 0.277
# item: ('vegetables', 'sandwich loaves') , 0.283
# item: ('vegetables', 'tortillas') , 0.284
# item: ('vegetables', 'butter') , 0.284
# item: ('vegetables', 'individual meals') , 0.285
# item: ('vegetables', 'pasta') , 0.286
# item: ('vegetables', 'shampoo') , 0.288
# item: ('vegetables', 'coffee/tea') , 0.290
# item: ('vegetables', 'paper towels') , 0.290
# item: ('vegetables', 'toilet paper') , 0.290
# item: ('vegetables', 'all- purpose') , 0.290
# item: ('fruits', 'vegetables') , 0.291
# item: ('vegetables', 'beef') , 0.291
# item: ('vegetables', 'ketchup') , 0.291
# item: ('vegetables', 'sandwich bags') , 0.293
# item: ('vegetables', 'juice') , 0.294
# item: ('vegetables', 'soap') , 0.295
# item: ('vegetables', 'milk') , 0.296
# item: ('vegetables', 'mixes') , 0.296
# item: ('vegetables', 'spaghetti sauce') , 0.297
# item: ('vegetables', 'sugar') , 0.298
# item: ('vegetables', 'bagels') , 0.300
# item: ('vegetables', 'ice cream') , 0.303
# item: ('vegetables', 'soda') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('vegetables', 'dinner rolls') , 0.308
# item: ('vegetables', 'laundry detergent') , 0.309
# item: ('vegetables', 'cheeses') , 0.309
# item: ('vegetables', 'aluminum foil') , 0.311
# item: ('vegetables', 'cereals') , 0.311
# item: ('vegetables', 'lunch meat') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('vegetables', 'yogurt') , 0.320
# item: ('vegetables', 'eggs') , 0.327
# item: ('vegetables', 'poultry') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('sandwich bags',) , 0.368
# item: ('butter',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('pasta',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('mixes',) , 0.376
# item: ('individual meals',) , 0.376
# item: ('juice',) , 0.377
# item: ('laundry detergent',) , 0.378
# item: ('toilet paper',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.385
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('soda',) , 0.391
# item: ('cheeses',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('vegetables',) ==> ('pork',) , 0.366
# Rule: ('vegetables',) ==> ('hand soap',) , 0.366
# Rule: ('vegetables',) ==> ('flour',) , 0.374
# Rule: ('vegetables',) ==> ('sandwich loaves',) , 0.382
# Rule: ('vegetables',) ==> ('tortillas',) , 0.384
# Rule: ('vegetables',) ==> ('butter',) , 0.384
# Rule: ('vegetables',) ==> ('individual meals',) , 0.386
# Rule: ('vegetables',) ==> ('pasta',) , 0.387
# Rule: ('vegetables',) ==> ('shampoo',) , 0.390
# Rule: ('vegetables',) ==> ('coffee/tea',) , 0.392
# Rule: ('vegetables',) ==> ('paper towels',) , 0.392
# Rule: ('vegetables',) ==> ('toilet paper',) , 0.392
# Rule: ('vegetables',) ==> ('all- purpose',) , 0.392
# Rule: ('vegetables',) ==> ('fruits',) , 0.393
# Rule: ('vegetables',) ==> ('beef',) , 0.394
# Rule: ('vegetables',) ==> ('ketchup',) , 0.394
# Rule: ('vegetables',) ==> ('sandwich bags',) , 0.397
# Rule: ('vegetables',) ==> ('juice',) , 0.398
# Rule: ('vegetables',) ==> ('soap',) , 0.399
# Rule: ('vegetables',) ==> ('milk',) , 0.400
# Rule: ('vegetables',) ==> ('mixes',) , 0.400
# Rule: ('vegetables',) ==> ('spaghetti sauce',) , 0.401
# Rule: ('vegetables',) ==> ('sugar',) , 0.403
# Rule: ('vegetables',) ==> ('bagels',) , 0.406
# Rule: ('vegetables',) ==> ('ice cream',) , 0.410
# Rule: ('vegetables',) ==> ('soda',) , 0.413
# Rule: ('vegetables',) ==> ('dishwashing liquid/detergent',) , 0.414
# Rule: ('vegetables',) ==> ('dinner rolls',) , 0.417
# Rule: ('vegetables',) ==> ('laundry detergent',) , 0.418
# Rule: ('vegetables',) ==> ('cheeses',) , 0.418
# Rule: ('vegetables',) ==> ('aluminum foil',) , 0.420
# Rule: ('vegetables',) ==> ('cereals',) , 0.420
# Rule: ('vegetables',) ==> ('lunch meat',) , 0.422
# Rule: ('vegetables',) ==> ('waffles',) , 0.426
# Rule: ('vegetables',) ==> ('yogurt',) , 0.432
# Rule: ('vegetables',) ==> ('eggs',) , 0.442
# Rule: ('vegetables',) ==> ('poultry',) , 0.449
# Rule: ('individual meals',) ==> ('vegetables',) , 0.759
# Rule: ('ice cream',) ==> ('vegetables',) , 0.760
# Rule: ('pork',) ==> ('vegetables',) , 0.760
# Rule: ('coffee/tea',) ==> ('vegetables',) , 0.764
# Rule: ('toilet paper',) ==> ('vegetables',) , 0.766
# Rule: ('tortillas',) ==> ('vegetables',) , 0.767
# Rule: ('pasta',) ==> ('vegetables',) , 0.771
# Rule: ('butter',) ==> ('vegetables',) , 0.771
# Rule: ('all- purpose',) ==> ('vegetables',) , 0.773
# Rule: ('beef',) ==> ('vegetables',) , 0.778
# Rule: ('soap',) ==> ('vegetables',) , 0.778
# Rule: ('milk',) ==> ('vegetables',) , 0.778
# Rule: ('bagels',) ==> ('vegetables',) , 0.779
# Rule: ('juice',) ==> ('vegetables',) , 0.781
# Rule: ('shampoo',) ==> ('vegetables',) , 0.781
# Rule: ('hand soap',) ==> ('vegetables',) , 0.782
# Rule: ('soda',) ==> ('vegetables',) , 0.782
# Rule: ('flour',) ==> ('vegetables',) , 0.784
# Rule: ('fruits',) ==> ('vegetables',) , 0.784
# Rule: ('ketchup',) ==> ('vegetables',) , 0.785
# Rule: ('cereals',) ==> ('vegetables',) , 0.785
# Rule: ('mixes',) ==> ('vegetables',) , 0.787
# Rule: ('poultry',) ==> ('vegetables',) , 0.787
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.789
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.790
# Rule: ('cheeses',) ==> ('vegetables',) , 0.791
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.792
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.795
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.797
# Rule: ('paper towels',) ==> ('vegetables',) , 0.799
# Rule: ('waffles',) ==> ('vegetables',) , 0.800
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.808
# Rule: ('sandwich loaves',) ==> ('vegetables',) , 0.809
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.817
# Rule: ('sugar',) ==> ('vegetables',) , 0.825
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #')  
print ('Case 2 (minimum support=0.30 and minimum confidence=0.50)') 
print ('Case 2 Reasoning: Items ocurring more than 30% in dataset. With more than 50% likeliness of items purchased together. \nKeeping average values for min_support and min_confidence we can see decrease in ocuurence of different items and decrease in items association.  ')
print ('Case 2 Output:') 
# %run apriori.py -f DATASET.csv -s 0.30 -c 0.50
# Out:
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #
# Case 2 (minimum support=0.30 and minimum confidence=0.80)
# Case 2 Reasoning: Items ocurring more than 30% in dataset. With more than 80% likeliness of items purchased together.
# Keeping average values for min_support and min_confidence we can see decrease in ocuurence of different items and decrease in items association.
# Case 2 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables', 'bagels') , 0.300
# item: ('vegetables', 'ice cream') , 0.303
# item: ('vegetables', 'soda') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('vegetables', 'dinner rolls') , 0.308
# item: ('vegetables', 'cheeses') , 0.309
# item: ('vegetables', 'laundry detergent') , 0.309
# item: ('vegetables', 'aluminum foil') , 0.311
# item: ('vegetables', 'cereals') , 0.311
# item: ('vegetables', 'lunch meat') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('vegetables', 'yogurt') , 0.320
# item: ('vegetables', 'eggs') , 0.327
# item: ('vegetables', 'poultry') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('sandwich bags',) , 0.368
# item: ('butter',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('pasta',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('mixes',) , 0.376
# item: ('individual meals',) , 0.376
# item: ('juice',) , 0.377
# item: ('laundry detergent',) , 0.378
# item: ('toilet paper',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.385
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('soda',) , 0.391
# item: ('cheeses',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('ice cream',) ==> ('vegetables',) , 0.760
# Rule: ('bagels',) ==> ('vegetables',) , 0.779
# Rule: ('soda',) ==> ('vegetables',) , 0.782
# Rule: ('cereals',) ==> ('vegetables',) , 0.785
# Rule: ('poultry',) ==> ('vegetables',) , 0.787
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.789
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.790
# Rule: ('cheeses',) ==> ('vegetables',) , 0.791
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.792
# Rule: ('waffles',) ==> ('vegetables',) , 0.800
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.808
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.817
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838

# %%
### print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=0.70 and minimum confidence=0.80)')
print ('Case 3 Reasoning: Items ocurring more than 70% in dataset. With more than 80% likeliness of items purchased together. \nKeeping high values for min_support and min_confidence we can see low ocuurence of frequent item set and zero items association. ')
print ('Case 3 Output:')
# %run apriori.py -f DATASET.csv -s 0.70 -c 0.80
# Out:
# Case 3 (minimum support=0.70 and minimum confidence=0.80)
# Case 3 Reasoning: Items ocurring more than 70% in dataset. With more than 80% likeliness of items purchased together.
# Keeping high values for min_support and min_confidence we can see low ocuurence of frequent item set and zero items association.
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [30 points] - Evaluate Results
